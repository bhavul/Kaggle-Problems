# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load in 

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the "../input/" directory.
# For example, running this (by clicking run or pressing Shift+Enter) will list the files in the input directory
from hyperdash import monitor_cell
import os
print(os.listdir("../input"))
import tensorflow as tf
from sklearn.cross_validation import train_test_split


# Any results you write to the current directory are saved as output.
# Out:
# ['test.csv', 'train.csv', 'gender_submission.csv']
# /Users/bhavul.g/.virtualenvs/ailearn/lib/python3.5/site-packages/sklearn/cross_validation.py:44: DeprecationWarning: This module was deprecated in version 0.18 in favor of the model_selection module into which all the refactored classes and functions are moved. Also note that the interface of the new CV iterators are different from that of this module. This module will be removed in 0.20.
#   "This module will be removed in 0.20.", DeprecationWarning)

# %%
def get_num_of_NaN_rows(df):
    return df.isnull().sum()

def fill_NaN_values_for_numerical_column(df, colname):
    df[colname] = df[colname].fillna(df[colname].mean())
    return df

def fill_NaN_values_for_categorical_column(df, colname, value):
    df[colname] = df[colname].fillna(value)
    return df

# %%
# Let's make a helper method from this now.
def find_categorical_columns(df):
    all_cols = df.columns
    numeric_cols = df._get_numeric_data().columns
    return set(all_cols) - set(numeric_cols)

# %%
# Let's make helper function here also
def convert_categorical_column_to_integer_values(df):
    df_numerical = df.copy()
    for col in find_categorical_columns(df):
        df_numerical[col] = df_numerical[col].astype('category')
        df_numerical[col] = df_numerical[col].cat.codes
    return df_numerical

# %%
# First, let's list our helper functions we could make from logic used above.
def convert_sigmoid_output_to_boolean_array(array, threshold):
    array = array > threshold
    return array

def convert_boolean_array_to_binary_array(array):
    array_binary = array.astype(int)
    return array_binary

# %%
### Tensorflow model
def model_generic(learning_rate, X_arg, Y_arg, X_dev, Y_dev, num_of_epochs, hidden_units, threshold):
    # 1. Placeholders to hold data
    X = tf.placeholder(tf.float32, [X_arg.shape[0],None])
    Y = tf.placeholder(tf.float32, [1, None])

    # 2. Model. 2 layers NN. So, W1, b1, W2, b2.
    # This is basically coding forward propagation formulaes
    W1 = tf.Variable(tf.random_normal((hidden_units,X_arg.shape[0])))
    b1 = tf.Variable(tf.zeros((hidden_units,1)))
    Z1 = tf.matmul(W1,X) + b1
    A1 = tf.nn.relu(Z1)

    W2 = tf.Variable(tf.random_normal((1, hidden_units)))
    b2 = tf.Variable(tf.zeros((1,1)))
    Z2 = tf.matmul(W2,A1) + b2
    A2 = tf.nn.sigmoid(Z2)

    # 3. Calculate cost
    cost = tf.nn.sigmoid_cross_entropy_with_logits(logits=Z2, labels=Y)
    cost_mean = tf.reduce_mean(cost)

    # 4. Optimizer (Gradient Descent / AdamOptimizer ) - Using this line, tensorflow automatically does backpropagation
    optimizer = tf.train.AdamOptimizer(learning_rate).minimize(cost_mean)
    
    # 5. Accuracy methods
    predicted_class = tf.greater(A2,threshold)
    prediction_arr = tf.equal(predicted_class, tf.equal(Y,1.0))
    accuracy = tf.reduce_mean(tf.cast(prediction_arr, tf.float32))
    
    # 5. initialize variabls
    session = tf.Session()
    tf.set_random_seed(1)
    init = tf.global_variables_initializer()
    session.run(init)
    
    # 6. Actual loop where learning happens
    for i in range(num_of_epochs):
        _, cost_mean_val, accuracy_val = session.run([optimizer, cost_mean, accuracy], feed_dict={X:X_arg, Y:Y_arg})
        if i % 5000 == 0 or i==(num_of_epochs-1):
            print("i:",i,", cost : ",cost_mean_val,", training accuracy : ",accuracy_val)
            
    return session.run([W1,b1,W2,b2,A2,Y,accuracy],feed_dict={X:X_dev, Y:Y_dev})

# %%
import math
# Ref : https://stackoverflow.com/questions/32109319/how-to-implement-the-relu-function-in-numpy
# Ref : https://stackoverflow.com/questions/3985619/how-to-calculate-a-logistic-sigmoid-function-in-python
def predict(W1,b1,W2,b2,X):
    
    Z1 = np.dot(W1,X) + b1
    A1 = np.maximum(Z1, 0, Z1)
    
    Z2 = np.dot(W2,A1) + b2
    A2 = 1 / (1 + np.exp(-Z2))
    return A2

# %%
# helper exercise which does the whole thing for any training dataframe given 
def execute_steps_for_titanic(columns_to_use, output_file_name, learning_rate=0.01, num_of_epochs=3000, hidden_units=50, threshold_for_output=0.5, ):
    # read data
    training_df_orig = pd.read_csv("../input/train.csv")
    testing_df_orig = pd.read_csv("../input/test.csv")
    # get X and Y separated
    train_df_Y = training_df_orig['Survived']
    train_df_X = training_df_orig[columns_to_use]
    test_df_X = testing_df_orig[columns_to_use]
    # fix missing data
    categorical_columns = find_categorical_columns(train_df_X)
    replace_values_dict = {'Embarked':'S', 'Cabin':'UNKNOWN'}
    for col in columns_to_use:
        num_of_NaN_rows = get_num_of_NaN_rows(train_df_X)[col]
        num_of_NaN_rows_test = get_num_of_NaN_rows(test_df_X)[col]
        if(num_of_NaN_rows > 0):
            print("Filling NaN values for column:",col)
            if col not in categorical_columns:
                train_df_X[col] = train_df_X[col].fillna(train_df_X[col].mean())
            else:
                train_df_X[col] = train_df_X[col].fillna(replace_values_dict[col])
        if(num_of_NaN_rows_test > 0):
            print("Filling NaN values for column:",col," in test data")
            if col not in categorical_columns:
                test_df_X[col] = test_df_X[col].fillna(test_df_X[col].mean())
            else:
                test_df_X[col] = test_df_X[col].fillna(replace_values_dict[col])
    print("Fixed NaN values in training and testing data.")
    # convert categorical to numerical data
    train_df_X_num = convert_categorical_column_to_integer_values(train_df_X)
    test_df_X_num = convert_categorical_column_to_integer_values(test_df_X)
    # Get numpy arrays for this data
    train_X = train_df_X_num.as_matrix()
    test_X = test_df_X_num.as_matrix()
    train_Y = train_df_Y.as_matrix()
    # fix rank-1 array created
    train_Y = train_Y[:,np.newaxis]
    # call model and get values 
    train_X_tr, train_X_dev, train_Y_tr, train_Y_dev = train_test_split(train_X, train_Y, test_size=0.3)
    W1,b1,W2,b2,A2,Y,final_tr_dev_accuracy = model_generic(learning_rate, train_X_tr.T, train_Y_tr.T, train_X_dev.T, train_Y_dev.T, num_of_epochs, hidden_units, threshold_for_output)
    print("Final training accuracy : ",final_tr_dev_accuracy)
    # get prediction and save it to output file
    prediction = predict(W1,b1,W2,b2,test_X.T)
    # if prediction value > threshold, then set as True, else as False
    prediction = prediction > threshold_for_output
    # Convert the True/False array to a 0 , 1 array
    prediction = prediction.astype(int)
    # Convert back to dataframe and give the column name as 'Survived'
    prediction_df = pd.DataFrame(data=prediction.T, columns=['Survived'])
    # Make a final data frame of the required output and output to csv
    final_df = pd.concat([testing_df_orig['PassengerId'], prediction_df], axis=1)
    final_file_name = output_file_name+"_tr_acc_"+"{0:.2f}".format(final_tr_dev_accuracy)+"_prediction.csv"
    final_df.to_csv(final_file_name, index=False)
    print("Done.")
    return final_file_name, final_tr_dev_accuracy

# %%
# %%monitor_cell "Titanic all variations"
#
# columns_to_use = ['Pclass','Sex','Age','SibSp','Parch','Ticket','Fare','Cabin','Embarked']
# learning_rates = [0.001, 0.005, 0.01]
# num_of_epochs_arr = [5000, 10000, 50000]
# hidden_units_arr = [3, 10, 50]
#
# for learning_rate in learning_rates:
#     for num_of_epochs in num_of_epochs_arr:
#         for hidden_units in hidden_units_arr:
#             filename, accuracy_val = execute_steps_for_titanic(columns_to_use, "dev", learning_rate=learning_rate, num_of_epochs=num_of_epochs, hidden_units=hidden_units, threshold_for_output=0.5)
#             print("\n","="*50)
#             print("[lr:",learning_rate,"][epoch:",num_of_epochs,"][hidden:",hidden_units,"][file:",filename,"] ACCURACY : ",accuracy_val)
#             print("="*50,"\n")
# Out:
# Filling NaN values for column: Age
# Filling NaN values for column: Age  in test data
# Filling NaN values for column: Fare  in test data
# Filling NaN values for column: Cabin
# Filling NaN values for column: Cabin  in test data
# Filling NaN values for column: Embarked
# Fixed NaN values in training and testing data.
# /Users/bhavul.g/.virtualenvs/ailearn/lib/python3.5/site-packages/ipykernel_launcher.py:19: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /Users/bhavul.g/.virtualenvs/ailearn/lib/python3.5/site-packages/ipykernel_launcher.py:25: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /Users/bhavul.g/.virtualenvs/ailearn/lib/python3.5/site-packages/ipykernel_launcher.py:21: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /Users/bhavul.g/.virtualenvs/ailearn/lib/python3.5/site-packages/ipykernel_launcher.py:27: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# i: 0 , cost :  45.7819 , training accuracy :  0.635634
# i: 4999 , cost :  0.60768 , training accuracy :  0.688604
# Final training accuracy :  0.66791
# Done.
#
#  ==================================================
# [lr: 0.001 ][epoch: 5000 ][hidden: 3 ][file: dev_tr_acc_0.67_prediction.csv ] ACCURACY :  0.66791
# ==================================================
#
# Filling NaN values for column: Age
# Filling NaN values for column: Age  in test data
# Filling NaN values for column: Fare  in test data
# Filling NaN values for column: Cabin
# Filling NaN values for column: Cabin  in test data
# Filling NaN values for column: Embarked
# Fixed NaN values in training and testing data.
# i: 0 , cost :  329.953 , training accuracy :  0.614767
# i: 4999 , cost :  0.624247 , training accuracy :  0.796148
# Final training accuracy :  0.772388
# Done.
#
#  ==================================================
# [lr: 0.001 ][epoch: 5000 ][hidden: 10 ][file: dev_tr_acc_0.77_prediction.csv ] ACCURACY :  0.772388
# ==================================================
#
# Filling NaN values for column: Age
# Filling NaN values for column: Age  in test data
# Filling NaN values for column: Fare  in test data
# Filling NaN values for column: Cabin
# Filling NaN values for column: Cabin  in test data
# Filling NaN values for column: Embarked
# Fixed NaN values in training and testing data.
# i: 0 , cost :  705.483 , training accuracy :  0.378812
# i: 4999 , cost :  0.596397 , training accuracy :  0.823435
# Final training accuracy :  0.701493
# Done.
#
#  ==================================================
# [lr: 0.001 ][epoch: 5000 ][hidden: 50 ][file: dev_tr_acc_0.70_prediction.csv ] ACCURACY :  0.701493
# ==================================================
#
# Filling NaN values for column: Age
# Filling NaN values for column: Age  in test data
# Filling NaN values for column: Fare  in test data
# Filling NaN values for column: Cabin
# Filling NaN values for column: Cabin  in test data
# Filling NaN values for column: Embarked
# Fixed NaN values in training and testing data.
# i: 0 , cost :  45.2025 , training accuracy :  0.378812
# i: 5000 , cost :  0.466526 , training accuracy :  0.804173
# i: 9999 , cost :  0.444711 , training accuracy :  0.800963
# Final training accuracy :  0.776119
# Done.
#
#  ==================================================
# [lr: 0.001 ][epoch: 10000 ][hidden: 3 ][file: dev_tr_acc_0.78_prediction.csv ] ACCURACY :  0.776119
# ==================================================
#
# Filling NaN values for column: Age
# Filling NaN values for column: Age  in test data
# Filling NaN values for column: Fare  in test data
# Filling NaN values for column: Cabin
# Filling NaN values for column: Cabin  in test data
# Filling NaN values for column: Embarked
# Fixed NaN values in training and testing data.
# i: 0 , cost :  339.062 , training accuracy :  0.382022
# i: 5000 , cost :  0.47737 , training accuracy :  0.797753
# i: 9999 , cost :  0.440077 , training accuracy :  0.807384
# Final training accuracy :  0.794776
# Done.
#
#  ==================================================
# [lr: 0.001 ][epoch: 10000 ][hidden: 10 ][file: dev_tr_acc_0.79_prediction.csv ] ACCURACY :  0.794776
# ==================================================
#
# Filling NaN values for column: Age
# Filling NaN values for column: Age  in test data
# Filling NaN values for column: Fare  in test data
# Filling NaN values for column: Cabin
# Filling NaN values for column: Cabin  in test data
# Filling NaN values for column: Embarked
# Fixed NaN values in training and testing data.
# i: 0 , cost :  160.408 , training accuracy :  0.619583
# i: 5000 , cost :  0.52752 , training accuracy :  0.810594
# i: 9999 , cost :  0.432259 , training accuracy :  0.831461
# Final training accuracy :  0.735075
# Done.
#
#  ==================================================
# [lr: 0.001 ][epoch: 10000 ][hidden: 50 ][file: dev_tr_acc_0.74_prediction.csv ] ACCURACY :  0.735075
# ==================================================
#
# Filling NaN values for column: Age
# Filling NaN values for column: Age  in test data
# Filling NaN values for column: Fare  in test data
# Filling NaN values for column: Cabin
# Filling NaN values for column: Cabin  in test data
# Filling NaN values for column: Embarked
# Fixed NaN values in training and testing data.
# i: 0 , cost :  98.0446 , training accuracy :  0.600321
# i: 5000 , cost :  0.671356 , training accuracy :  0.603531
# i: 10000 , cost :  0.615164 , training accuracy :  0.691814
# i: 15000 , cost :  0.432579 , training accuracy :  0.820225
# i: 20000 , cost :  0.432576 , training accuracy :  0.817014
# i: 25000 , cost :  0.432585 , training accuracy :  0.820225
# i: 30000 , cost :  0.432575 , training accuracy :  0.817014
# i: 35000 , cost :  0.432576 , training accuracy :  0.81862
# i: 40000 , cost :  0.432616 , training accuracy :  0.82183
# i: 45000 , cost :  0.432585 , training accuracy :  0.820225
# i: 49999 , cost :  0.43258 , training accuracy :  0.81862
# Final training accuracy :  0.80597
# Done.
#
#  ==================================================
# [lr: 0.001 ][epoch: 50000 ][hidden: 3 ][file: dev_tr_acc_0.81_prediction.csv ] ACCURACY :  0.80597
# ==================================================
#
# Filling NaN values for column: Age
# Filling NaN values for column: Age  in test data
# Filling NaN values for column: Fare  in test data
# Filling NaN values for column: Cabin
# Filling NaN values for column: Cabin  in test data
# Filling NaN values for column: Embarked
# Fixed NaN values in training and testing data.
# i: 0 , cost :  101.308 , training accuracy :  0.452648
# i: 5000 , cost :  0.420715 , training accuracy :  0.817014
# i: 10000 , cost :  0.412266 , training accuracy :  0.815409
# i: 15000 , cost :  0.400968 , training accuracy :  0.82504
# i: 20000 , cost :  0.38903 , training accuracy :  0.842697
# i: 25000 , cost :  0.386247 , training accuracy :  0.841092
# i: 30000 , cost :  0.384902 , training accuracy :  0.844302
# i: 35000 , cost :  0.387882 , training accuracy :  0.836276
# i: 40000 , cost :  0.386268 , training accuracy :  0.837881
# i: 45000 , cost :  0.384202 , training accuracy :  0.841092
# i: 49999 , cost :  0.405279 , training accuracy :  0.833066
# Final training accuracy :  0.787313
# Done.
#
#  ==================================================
# [lr: 0.001 ][epoch: 50000 ][hidden: 10 ][file: dev_tr_acc_0.79_prediction.csv ] ACCURACY :  0.787313
# ==================================================
#
# Filling NaN values for column: Age
# Filling NaN values for column: Age  in test data
# Filling NaN values for column: Fare  in test data
# Filling NaN values for column: Cabin
# Filling NaN values for column: Cabin  in test data
# Filling NaN values for column: Embarked
# Fixed NaN values in training and testing data.
# i: 0 , cost :  1664.35 , training accuracy :  0.365971
# i: 5000 , cost :  0.719358 , training accuracy :  0.829856
# i: 10000 , cost :  0.369282 , training accuracy :  0.860353
# i: 15000 , cost :  0.330334 , training accuracy :  0.860353
# i: 20000 , cost :  0.306845 , training accuracy :  0.866774
# i: 25000 , cost :  0.323081 , training accuracy :  0.87801
# i: 30000 , cost :  0.278208 , training accuracy :  0.890851
# i: 35000 , cost :  0.293417 , training accuracy :  0.88443
# i: 40000 , cost :  0.295284 , training accuracy :  0.886035
# i: 45000 , cost :  0.29112 , training accuracy :  0.88443
# i: 49999 , cost :  0.298561 , training accuracy :  0.874799
# Final training accuracy :  0.716418
# Done.
#
#  ==================================================
# [lr: 0.001 ][epoch: 50000 ][hidden: 50 ][file: dev_tr_acc_0.72_prediction.csv ] ACCURACY :  0.716418
# ==================================================
#
# Filling NaN values for column: Age
# Filling NaN values for column: Age  in test data
# Filling NaN values for column: Fare  in test data
# Filling NaN values for column: Cabin
# Filling NaN values for column: Cabin  in test data
# Filling NaN values for column: Embarked
# Fixed NaN values in training and testing data.
# i: 0 , cost :  138.684 , training accuracy :  0.619583
# i: 4999 , cost :  0.662023 , training accuracy :  0.621188
# Final training accuracy :  0.608209
# Done.
#
#  ==================================================
# [lr: 0.005 ][epoch: 5000 ][hidden: 3 ][file: dev_tr_acc_0.61_prediction.csv ] ACCURACY :  0.608209
# ==================================================
#
# Filling NaN values for column: Age
# Filling NaN values for column: Age  in test data
# Filling NaN values for column: Fare  in test data
# Filling NaN values for column: Cabin
# Filling NaN values for column: Cabin  in test data
# Filling NaN values for column: Embarked
# Fixed NaN values in training and testing data.
# i: 0 , cost :  1823.36 , training accuracy :  0.370787
# i: 4999 , cost :  0.443344 , training accuracy :  0.805779
# Final training accuracy :  0.772388
# Done.
#
#  ==================================================
# [lr: 0.005 ][epoch: 5000 ][hidden: 10 ][file: dev_tr_acc_0.77_prediction.csv ] ACCURACY :  0.772388
# ==================================================
#
# Filling NaN values for column: Age
# Filling NaN values for column: Age  in test data
# Filling NaN values for column: Fare  in test data
# Filling NaN values for column: Cabin
# Filling NaN values for column: Cabin  in test data
# Filling NaN values for column: Embarked
# Fixed NaN values in training and testing data.
# i: 0 , cost :  320.567 , training accuracy :  0.654896
# i: 4999 , cost :  0.550249 , training accuracy :  0.847512
# Final training accuracy :  0.742537
# Done.
#
#  ==================================================
# [lr: 0.005 ][epoch: 5000 ][hidden: 50 ][file: dev_tr_acc_0.74_prediction.csv ] ACCURACY :  0.742537
# ==================================================
#
# Filling NaN values for column: Age
# Filling NaN values for column: Age  in test data
# Filling NaN values for column: Fare  in test data
# Filling NaN values for column: Cabin
# Filling NaN values for column: Cabin  in test data
# Filling NaN values for column: Embarked
# Fixed NaN values in training and testing data.
# i: 0 , cost :  295.313 , training accuracy :  0.617977
# i: 5000 , cost :  0.422239 , training accuracy :  0.829856
# i: 9999 , cost :  0.409253 , training accuracy :  0.837881
# Final training accuracy :  0.75
# Done.
#
#  ==================================================
# [lr: 0.005 ][epoch: 10000 ][hidden: 3 ][file: dev_tr_acc_0.75_prediction.csv ] ACCURACY :  0.75
# ==================================================
#
# Filling NaN values for column: Age
# Filling NaN values for column: Age  in test data
# Filling NaN values for column: Fare  in test data
# Filling NaN values for column: Cabin
# Filling NaN values for column: Cabin  in test data
# Filling NaN values for column: Embarked
# Fixed NaN values in training and testing data.
# i: 0 , cost :  163.745 , training accuracy :  0.622793
# i: 5000 , cost :  0.39348 , training accuracy :  0.842697
# i: 9999 , cost :  0.375763 , training accuracy :  0.826645
# Final training accuracy :  0.772388
# Done.
#
#  ==================================================
# [lr: 0.005 ][epoch: 10000 ][hidden: 10 ][file: dev_tr_acc_0.77_prediction.csv ] ACCURACY :  0.772388
# ==================================================
#
# Filling NaN values for column: Age
# Filling NaN values for column: Age  in test data
# Filling NaN values for column: Fare  in test data
# Filling NaN values for column: Cabin
# Filling NaN values for column: Cabin  in test data
# Filling NaN values for column: Embarked
# Fixed NaN values in training and testing data.
# i: 0 , cost :  412.328 , training accuracy :  0.622793
# i: 5000 , cost :  1.26681 , training accuracy :  0.796148
# i: 9999 , cost :  0.401792 , training accuracy :  0.873194
# Final training accuracy :  0.753731
# Done.
#
#  ==================================================
# [lr: 0.005 ][epoch: 10000 ][hidden: 50 ][file: dev_tr_acc_0.75_prediction.csv ] ACCURACY :  0.753731
# ==================================================
#
# Filling NaN values for column: Age
# Filling NaN values for column: Age  in test data
# Filling NaN values for column: Fare  in test data
# Filling NaN values for column: Cabin
# Filling NaN values for column: Cabin  in test data
# Filling NaN values for column: Embarked
# Fixed NaN values in training and testing data.
# i: 0 , cost :  11.8258 , training accuracy :  0.592295
# i: 5000 , cost :  0.654552 , training accuracy :  0.622793
# i: 10000 , cost :  0.64009 , training accuracy :  0.635634
# i: 15000 , cost :  0.612064 , training accuracy :  0.662921
# i: 20000 , cost :  0.60639 , training accuracy :  0.669342
# i: 25000 , cost :  0.595829 , training accuracy :  0.680578
# i: 30000 , cost :  0.600099 , training accuracy :  0.675762
# i: 35000 , cost :  0.596326 , training accuracy :  0.678973
# i: 40000 , cost :  0.591683 , training accuracy :  0.683788
# i: 45000 , cost :  0.619546 , training accuracy :  0.656501
# i: 49999 , cost :  0.619546 , training accuracy :  0.656501
# Final training accuracy :  0.66791
# Done.
#
#  ==================================================
# [lr: 0.005 ][epoch: 50000 ][hidden: 3 ][file: dev_tr_acc_0.67_prediction.csv ] ACCURACY :  0.66791
# ==================================================
#
# Filling NaN values for column: Age
# Filling NaN values for column: Age  in test data
# Filling NaN values for column: Fare  in test data
# Filling NaN values for column: Cabin
# Filling NaN values for column: Cabin  in test data
# Filling NaN values for column: Embarked
# Fixed NaN values in training and testing data.
# i: 0 , cost :  45.596 , training accuracy :  0.304976
# i: 5000 , cost :  0.421986 , training accuracy :  0.804173
# i: 10000 , cost :  0.40664 , training accuracy :  0.800963
# i: 15000 , cost :  0.390816 , training accuracy :  0.808989
# i: 20000 , cost :  0.388351 , training accuracy :  0.82504
# i: 25000 , cost :  0.388071 , training accuracy :  0.82183
# i: 30000 , cost :  0.388254 , training accuracy :  0.826645
# i: 35000 , cost :  0.388529 , training accuracy :  0.810594
# i: 40000 , cost :  0.387712 , training accuracy :  0.81862
# i: 45000 , cost :  0.393736 , training accuracy :  0.826645
# i: 49999 , cost :  0.389708 , training accuracy :  0.82825
# Final training accuracy :  0.791045
# Done.
#
#  ==================================================
# [lr: 0.005 ][epoch: 50000 ][hidden: 10 ][file: dev_tr_acc_0.79_prediction.csv ] ACCURACY :  0.791045
# ==================================================
#
# Filling NaN values for column: Age
# Filling NaN values for column: Age  in test data
# Filling NaN values for column: Fare  in test data
# Filling NaN values for column: Cabin
# Filling NaN values for column: Cabin  in test data
# Filling NaN values for column: Embarked
# Fixed NaN values in training and testing data.
# i: 0 , cost :  993.436 , training accuracy :  0.632424
# i: 5000 , cost :  0.402483 , training accuracy :  0.866774
# i: 10000 , cost :  1.72767 , training accuracy :  0.642055
# i: 15000 , cost :  3.06174 , training accuracy :  0.775281
# i: 20000 , cost :  0.347535 , training accuracy :  0.890851
# i: 25000 , cost :  0.817191 , training accuracy :  0.847512
# i: 30000 , cost :  0.786249 , training accuracy :  0.730337
# i: 35000 , cost :  0.366497 , training accuracy :  0.876405
# i: 40000 , cost :  0.842043 , training accuracy :  0.858748
# i: 45000 , cost :  0.455421 , training accuracy :  0.874799
# i: 49999 , cost :  0.412281 , training accuracy :  0.868379
# Final training accuracy :  0.727612
# Done.
#
#  ==================================================
# [lr: 0.005 ][epoch: 50000 ][hidden: 50 ][file: dev_tr_acc_0.73_prediction.csv ] ACCURACY :  0.727612
# ==================================================
#
# Filling NaN values for column: Age
# Filling NaN values for column: Age  in test data
# Filling NaN values for column: Fare  in test data
# Filling NaN values for column: Cabin
# Filling NaN values for column: Cabin  in test data
# Filling NaN values for column: Embarked
# Fixed NaN values in training and testing data.
# i: 0 , cost :  84.3922 , training accuracy :  0.4061
# i: 4999 , cost :  0.462785 , training accuracy :  0.799358
# Final training accuracy :  0.843284
# Done.
#
#  ==================================================
# [lr: 0.01 ][epoch: 5000 ][hidden: 3 ][file: dev_tr_acc_0.84_prediction.csv ] ACCURACY :  0.843284
# ==================================================
#
# Filling NaN values for column: Age
# Filling NaN values for column: Age  in test data
# Filling NaN values for column: Fare  in test data
# Filling NaN values for column: Cabin
# Filling NaN values for column: Cabin  in test data
# Filling NaN values for column: Embarked
# Fixed NaN values in training and testing data.
# i: 0 , cost :  54.1507 , training accuracy :  0.630819
# i: 4999 , cost :  0.400007 , training accuracy :  0.82504
# Final training accuracy :  0.779851
# Done.
#
#  ==================================================
# [lr: 0.01 ][epoch: 5000 ][hidden: 10 ][file: dev_tr_acc_0.78_prediction.csv ] ACCURACY :  0.779851
# ==================================================
#
# Filling NaN values for column: Age
# Filling NaN values for column: Age  in test data
# Filling NaN values for column: Fare  in test data
# Filling NaN values for column: Cabin
# Filling NaN values for column: Cabin  in test data
# Filling NaN values for column: Embarked
# Fixed NaN values in training and testing data.
# i: 0 , cost :  399.464 , training accuracy :  0.34992
# i: 4999 , cost :  0.817781 , training accuracy :  0.869984
# Final training accuracy :  0.794776
# Done.
#
#  ==================================================
# [lr: 0.01 ][epoch: 5000 ][hidden: 50 ][file: dev_tr_acc_0.79_prediction.csv ] ACCURACY :  0.794776
# ==================================================
#
# Filling NaN values for column: Age
# Filling NaN values for column: Age  in test data
# Filling NaN values for column: Fare  in test data
# Filling NaN values for column: Cabin
# Filling NaN values for column: Cabin  in test data
# Filling NaN values for column: Embarked
# Fixed NaN values in training and testing data.
# i: 0 , cost :  24.7845 , training accuracy :  0.487961
# i: 5000 , cost :  0.622705 , training accuracy :  0.667737
# i: 9999 , cost :  0.446973 , training accuracy :  0.807384
# Final training accuracy :  0.809702
# Done.
#
#  ==================================================
# [lr: 0.01 ][epoch: 10000 ][hidden: 3 ][file: dev_tr_acc_0.81_prediction.csv ] ACCURACY :  0.809702
# ==================================================
#
# Filling NaN values for column: Age
# Filling NaN values for column: Age  in test data
# Filling NaN values for column: Fare  in test data
# Filling NaN values for column: Cabin
# Filling NaN values for column: Cabin  in test data
# Filling NaN values for column: Embarked
# Fixed NaN values in training and testing data.
# i: 0 , cost :  247.281 , training accuracy :  0.632424
# i: 5000 , cost :  0.548676 , training accuracy :  0.76244
# i: 9999 , cost :  0.490066 , training accuracy :  0.773676
# Final training accuracy :  0.69403
# Done.
#
#  ==================================================
# [lr: 0.01 ][epoch: 10000 ][hidden: 10 ][file: dev_tr_acc_0.69_prediction.csv ] ACCURACY :  0.69403
# ==================================================
#
# Filling NaN values for column: Age
# Filling NaN values for column: Age  in test data
# Filling NaN values for column: Fare  in test data
# Filling NaN values for column: Cabin
# Filling NaN values for column: Cabin  in test data
# Filling NaN values for column: Embarked
# Fixed NaN values in training and testing data.
# i: 0 , cost :  215.96 , training accuracy :  0.634029
# i: 5000 , cost :  0.440451 , training accuracy :  0.873194
# i: 9999 , cost :  0.287729 , training accuracy :  0.894061
# Final training accuracy :  0.783582
# Done.
#
#  ==================================================
# [lr: 0.01 ][epoch: 10000 ][hidden: 50 ][file: dev_tr_acc_0.78_prediction.csv ] ACCURACY :  0.783582
# ==================================================
#
# Filling NaN values for column: Age
# Filling NaN values for column: Age  in test data
# Filling NaN values for column: Fare  in test data
# Filling NaN values for column: Cabin
# Filling NaN values for column: Cabin  in test data
# Filling NaN values for column: Embarked
# Fixed NaN values in training and testing data.
# i: 0 , cost :  22.6992 , training accuracy :  0.59069
# i: 5000 , cost :  0.434806 , training accuracy :  0.807384
# i: 10000 , cost :  0.437603 , training accuracy :  0.804173
# i: 15000 , cost :  0.434286 , training accuracy :  0.805779
# i: 20000 , cost :  0.443558 , training accuracy :  0.791332
# i: 25000 , cost :  0.462169 , training accuracy :  0.786517
# i: 30000 , cost :  0.433918 , training accuracy :  0.807384
# i: 35000 , cost :  0.439918 , training accuracy :  0.797753
# i: 40000 , cost :  0.434406 , training accuracy :  0.808989
# i: 45000 , cost :  0.445805 , training accuracy :  0.797753
# i: 49999 , cost :  0.442257 , training accuracy :  0.794543
# Final training accuracy :  0.791045
# Done.
#
#  ==================================================
# [lr: 0.01 ][epoch: 50000 ][hidden: 3 ][file: dev_tr_acc_0.79_prediction.csv ] ACCURACY :  0.791045
# ==================================================
#
# Filling NaN values for column: Age
# Filling NaN values for column: Age  in test data
# Filling NaN values for column: Fare  in test data
# Filling NaN values for column: Cabin
# Filling NaN values for column: Cabin  in test data
# Filling NaN values for column: Embarked
# Fixed NaN values in training and testing data.
# i: 0 , cost :  432.159 , training accuracy :  0.58748
# i: 5000 , cost :  0.425689 , training accuracy :  0.817014
# i: 10000 , cost :  0.409515 , training accuracy :  0.823435
# i: 15000 , cost :  0.391098 , training accuracy :  0.839486
# i: 20000 , cost :  0.393046 , training accuracy :  0.831461
# i: 25000 , cost :  0.367371 , training accuracy :  0.836276
# i: 30000 , cost :  0.383043 , training accuracy :  0.834671
# i: 35000 , cost :  0.385411 , training accuracy :  0.833066
# i: 40000 , cost :  0.367599 , training accuracy :  0.841092
# i: 45000 , cost :  0.380809 , training accuracy :  0.842697
# i: 49999 , cost :  0.365225 , training accuracy :  0.844302
# Final training accuracy :  0.772388
# Done.
#
#  ==================================================
# [lr: 0.01 ][epoch: 50000 ][hidden: 10 ][file: dev_tr_acc_0.77_prediction.csv ] ACCURACY :  0.772388
# ==================================================
#
# Filling NaN values for column: Age
# Filling NaN values for column: Age  in test data
# Filling NaN values for column: Fare  in test data
# Filling NaN values for column: Cabin
# Filling NaN values for column: Cabin  in test data
# Filling NaN values for column: Embarked
# Fixed NaN values in training and testing data.
# i: 0 , cost :  2723.16 , training accuracy :  0.388443
# i: 5000 , cost :  2.64293 , training accuracy :  0.760835
# i: 10000 , cost :  8.6554 , training accuracy :  0.420546
# i: 15000 , cost :  1.97892 , training accuracy :  0.796148
# i: 20000 , cost :  8.15975 , training accuracy :  0.436597
# i: 25000 , cost :  1.62852 , training accuracy :  0.834671
# i: 30000 , cost :  0.687041 , training accuracy :  0.850722
# i: 35000 , cost :  0.856785 , training accuracy :  0.865169
# i: 40000 , cost :  0.3051 , training accuracy :  0.894061
# i: 45000 , cost :  0.280913 , training accuracy :  0.902087
# i: 49999 , cost :  0.419817 , training accuracy :  0.892456
# Final training accuracy :  0.768657
# Done.
#
#  ==================================================
# [lr: 0.01 ][epoch: 50000 ][hidden: 50 ][file: dev_tr_acc_0.77_prediction.csv ] ACCURACY :  0.768657
# ==================================================
#
# This run of "Titanic all variations" ran for 0:15:31 and logs are available locally at: /Users/bhavul.g/.hyperdash/logs/titanic-all-variations/titanic-all-variations_2018-04-17t17-45-02-770392.log
# /Users/bhavul.g/.virtualenvs/ailearn/lib/python3.5/site-packages/ipykernel_launcher.py:10: RuntimeWarning: overflow encountered in exp
#   # Remove the CWD from sys.path while we load stuff.

# %%
# %%monitor_cell "Titanic all variations - Name also included"
#
# columns_to_use = ['Name','Pclass','Sex','Age','SibSp','Parch','Ticket','Fare','Cabin','Embarked']
# learning_rates = [0.005, 0.01]
# num_of_epochs_arr = [5000, 10000]
# hidden_units_arr = [3, 5, 10]
#
# for learning_rate in learning_rates:
#     for num_of_epochs in num_of_epochs_arr:
#         for hidden_units in hidden_units_arr:
#             filename, accuracy_val = execute_steps_for_titanic(columns_to_use, "dev", learning_rate=learning_rate, num_of_epochs=num_of_epochs, hidden_units=hidden_units, threshold_for_output=0.5)
#             print("\n","="*50)
#             print("[lr:",learning_rate,"][epoch:",num_of_epochs,"][hidden:",hidden_units,"][file:",filename,"] ACCURACY : ",accuracy_val)
#             print("="*50,"\n")
# Out:
# Filling NaN values for column: Age
# Filling NaN values for column: Age  in test data
# Filling NaN values for column: Fare  in test data
# /Users/bhavul.g/.virtualenvs/ailearn/lib/python3.5/site-packages/ipykernel_launcher.py:19: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /Users/bhavul.g/.virtualenvs/ailearn/lib/python3.5/site-packages/ipykernel_launcher.py:25: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# Filling NaN values for column: Cabin
# Filling NaN values for column: Cabin  in test data
# Filling NaN values for column: Embarked
# Fixed NaN values in training and testing data.
# i: 0 , cost :  953.734 , training accuracy :  0.386838
# /Users/bhavul.g/.virtualenvs/ailearn/lib/python3.5/site-packages/ipykernel_launcher.py:21: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /Users/bhavul.g/.virtualenvs/ailearn/lib/python3.5/site-packages/ipykernel_launcher.py:27: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# i: 4999 , cost :  0.445757 , training accuracy :  0.81862
# Final training accuracy :  0.746269
# Done.
#
#  ==================================================
# [lr: 0.005 ][epoch: 5000 ][hidden: 3 ][file: dev_tr_acc_0.75_prediction.csv ] ACCURACY :  0.746269
# ==================================================
#
# Filling NaN values for column: Age
# Filling NaN values for column: Age  in test data
# Filling NaN values for column: Fare  in test data
# Filling NaN values for column: Cabin
# Filling NaN values for column: Cabin  in test data
# Filling NaN values for column: Embarked
# Fixed NaN values in training and testing data.
# i: 0 , cost :  165.126 , training accuracy :  0.627608
# i: 4999 , cost :  0.42519 , training accuracy :  0.82183
# Final training accuracy :  0.753731
# Done.
#
#  ==================================================
# [lr: 0.005 ][epoch: 5000 ][hidden: 5 ][file: dev_tr_acc_0.75_prediction.csv ] ACCURACY :  0.753731
# ==================================================
#
# Filling NaN values for column: Age
# Filling NaN values for column: Age  in test data
# Filling NaN values for column: Fare  in test data
# Filling NaN values for column: Cabin
# Filling NaN values for column: Cabin  in test data
# Filling NaN values for column: Embarked
# Fixed NaN values in training and testing data.
# i: 0 , cost :  851.324 , training accuracy :  0.396469
# i: 4999 , cost :  0.527681 , training accuracy :  0.789727
# Final training accuracy :  0.716418
# Done.
#
#  ==================================================
# [lr: 0.005 ][epoch: 5000 ][hidden: 10 ][file: dev_tr_acc_0.72_prediction.csv ] ACCURACY :  0.716418
# ==================================================
#
# Filling NaN values for column: Age
# Filling NaN values for column: Age  in test data
# Filling NaN values for column: Fare  in test data
# Filling NaN values for column: Cabin
# Filling NaN values for column: Cabin  in test data
# Filling NaN values for column: Embarked
# Fixed NaN values in training and testing data.
# i: 0 , cost :  192.316 , training accuracy :  0.390048
# i: 5000 , cost :  0.529963 , training accuracy :  0.720706
# i: 9999 , cost :  0.527687 , training accuracy :  0.723917
# Final training accuracy :  0.716418
# Done.
#
#  ==================================================
# [lr: 0.005 ][epoch: 10000 ][hidden: 3 ][file: dev_tr_acc_0.72_prediction.csv ] ACCURACY :  0.716418
# ==================================================
#
# Filling NaN values for column: Age
# Filling NaN values for column: Age  in test data
# Filling NaN values for column: Fare  in test data
# Filling NaN values for column: Cabin
# Filling NaN values for column: Cabin  in test data
# Filling NaN values for column: Embarked
# Fixed NaN values in training and testing data.
# i: 0 , cost :  503.783 , training accuracy :  0.364366
# i: 5000 , cost :  0.592412 , training accuracy :  0.725522
# i: 9999 , cost :  0.424353 , training accuracy :  0.810594
# Final training accuracy :  0.80597
# Done.
#
#  ==================================================
# [lr: 0.005 ][epoch: 10000 ][hidden: 5 ][file: dev_tr_acc_0.81_prediction.csv ] ACCURACY :  0.80597
# ==================================================
#
# Filling NaN values for column: Age
# Filling NaN values for column: Age  in test data
# Filling NaN values for column: Fare  in test data
# Filling NaN values for column: Cabin
# Filling NaN values for column: Cabin  in test data
# Filling NaN values for column: Embarked
# Fixed NaN values in training and testing data.
# i: 0 , cost :  2576.53 , training accuracy :  0.378812
# i: 5000 , cost :  0.621606 , training accuracy :  0.792937
# i: 9999 , cost :  0.507098 , training accuracy :  0.792937
# Final training accuracy :  0.772388
# Done.
#
#  ==================================================
# [lr: 0.005 ][epoch: 10000 ][hidden: 10 ][file: dev_tr_acc_0.77_prediction.csv ] ACCURACY :  0.772388
# ==================================================
#
# Filling NaN values for column: Age
# Filling NaN values for column: Age  in test data
# Filling NaN values for column: Fare  in test data
# Filling NaN values for column: Cabin
# Filling NaN values for column: Cabin  in test data
# Filling NaN values for column: Embarked
# Fixed NaN values in training and testing data.
# i: 0 , cost :  105.658 , training accuracy :  0.621188
# i: 4999 , cost :  0.667635 , training accuracy :  0.609952
# Final training accuracy :  0.630597
# Done.
#
#  ==================================================
# [lr: 0.01 ][epoch: 5000 ][hidden: 3 ][file: dev_tr_acc_0.63_prediction.csv ] ACCURACY :  0.630597
# ==================================================
#
# Filling NaN values for column: Age
# Filling NaN values for column: Age  in test data
# Filling NaN values for column: Fare  in test data
# Filling NaN values for column: Cabin
# Filling NaN values for column: Cabin  in test data
# Filling NaN values for column: Embarked
# Fixed NaN values in training and testing data.
# i: 0 , cost :  1058.2 , training accuracy :  0.386838
# i: 4999 , cost :  0.657625 , training accuracy :  0.630819
# Final training accuracy :  0.615672
# Done.
#
#  ==================================================
# [lr: 0.01 ][epoch: 5000 ][hidden: 5 ][file: dev_tr_acc_0.62_prediction.csv ] ACCURACY :  0.615672
# ==================================================
#
# Filling NaN values for column: Age
# Filling NaN values for column: Age  in test data
# Filling NaN values for column: Fare  in test data
# Filling NaN values for column: Cabin
# Filling NaN values for column: Cabin  in test data
# Filling NaN values for column: Embarked
# Fixed NaN values in training and testing data.
# i: 0 , cost :  1306.75 , training accuracy :  0.388443
# i: 4999 , cost :  1.13048 , training accuracy :  0.744783
# Final training accuracy :  0.69403
# Done.
#
#  ==================================================
# [lr: 0.01 ][epoch: 5000 ][hidden: 10 ][file: dev_tr_acc_0.69_prediction.csv ] ACCURACY :  0.69403
# ==================================================
#
# Filling NaN values for column: Age
# Filling NaN values for column: Age  in test data
# Filling NaN values for column: Fare  in test data
# Filling NaN values for column: Cabin
# Filling NaN values for column: Cabin  in test data
# Filling NaN values for column: Embarked
# Fixed NaN values in training and testing data.
# i: 0 , cost :  0.693146 , training accuracy :  0.622793
# i: 5000 , cost :  0.66268 , training accuracy :  0.622793
# i: 9999 , cost :  0.66268 , training accuracy :  0.622793
# Final training accuracy :  0.600746
# Done.
#
#  ==================================================
# [lr: 0.01 ][epoch: 10000 ][hidden: 3 ][file: dev_tr_acc_0.60_prediction.csv ] ACCURACY :  0.600746
# ==================================================
#
# Filling NaN values for column: Age
# Filling NaN values for column: Age  in test data
# Filling NaN values for column: Fare  in test data
# Filling NaN values for column: Cabin
# Filling NaN values for column: Cabin  in test data
# Filling NaN values for column: Embarked
# Fixed NaN values in training and testing data.
# i: 0 , cost :  149.211 , training accuracy :  0.394864
# i: 5000 , cost :  0.606166 , training accuracy :  0.677368
# i: 9999 , cost :  0.407547 , training accuracy :  0.845907
# Final training accuracy :  0.787313
# Done.
#
#  ==================================================
# [lr: 0.01 ][epoch: 10000 ][hidden: 5 ][file: dev_tr_acc_0.79_prediction.csv ] ACCURACY :  0.787313
# ==================================================
#
# Filling NaN values for column: Age
# Filling NaN values for column: Age  in test data
# Filling NaN values for column: Fare  in test data
# Filling NaN values for column: Cabin
# Filling NaN values for column: Cabin  in test data
# Filling NaN values for column: Embarked
# Fixed NaN values in training and testing data.
# i: 0 , cost :  399.744 , training accuracy :  0.629214
# i: 5000 , cost :  0.582999 , training accuracy :  0.743178
# i: 9999 , cost :  0.62556 , training accuracy :  0.780096
# Final training accuracy :  0.813433
# Done.
#
#  ==================================================
# [lr: 0.01 ][epoch: 10000 ][hidden: 10 ][file: dev_tr_acc_0.81_prediction.csv ] ACCURACY :  0.813433
# ==================================================
#
# This run of "Titanic all variations - Name also included" ran for 0:02:32 and logs are available locally at: /Users/bhavul.g/.hyperdash/logs/titanic-all-variations-name-also-included/titanic-all-variations-name-also-included_2018-04-17t18-30-18-910325.log
